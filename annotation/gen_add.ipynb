# %% [markdown]
# # AB Image Pair Description Generator
#
# 使用 GPT-5mini 为图片对生成变化描述和机器人指令

# %% [markdown]
# ## 1. 参数配置
#
# 在这里配置所有需要的参数

# %%
# =====================================================
# 参数配置区 - 请在这里修改参数
# =====================================================

# OpenAI API Key (必填)
OPENAI_API_KEY = ""

# OpenAI 模型 (gpt-4o, gpt-4o-mini 等)
MODEL = "gpt-5-mini"

# 输入目录，包含 pair_* 文件夹
INPUT_DIR = "/home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items"

# 最大输出 token 数
MAX_OUTPUT_TOKENS = 8000

# %% [markdown]
# ## 2. 导入依赖和设置 API Key

# %%
import os
import base64
import json
import re
import math
from dataclasses import dataclass
from pathlib import Path
from typing import Any, Dict, List, Optional, Tuple

# 设置 API Key
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

from openai import OpenAI

print("依赖导入成功！")
# Out:
# 依赖导入成功！

# %% [markdown]
# ## 3. 数据结构和工具函数

# %%
@dataclass
class ObjectSpec:
    """对象规格：包含ID、像素坐标和世界坐标（世界坐标仅用于你在外部计算距离）"""
    object_id: str
    pixel_center_a: Tuple[int, int]
    pixel_center_b: Optional[Tuple[int, int]] = None
    world_coordinate_a: Optional[Tuple[float, float, float]] = None
    world_coordinate_b: Optional[Tuple[float, float, float]] = None
    move_distance_m: Optional[float] = None


def image_to_data_url(image_path: str) -> str:
    """
    将本地图片转换为 data URL，用于 OpenAI API。
    支持格式: PNG/JPEG/WEBP/GIF
    """
    p = Path(image_path)
    if not p.exists():
        raise FileNotFoundError(f"Image not found: {image_path}")

    suffix = p.suffix.lower().lstrip(".")
    mime_map = {
        "png": "image/png",
        "jpg": "image/jpeg",
        "jpeg": "image/jpeg",
        "webp": "image/webp",
        "gif": "image/gif",
    }
    if suffix not in mime_map:
        raise ValueError(f"Unsupported image type: .{suffix}")

    b64 = base64.b64encode(p.read_bytes()).decode("utf-8")
    return f"data:{mime_map[suffix]};base64,{b64}"


def save_json(path: str, obj: Dict[str, Any]) -> None:
    """保存 JSON 文件"""
    Path(path).write_text(json.dumps(obj, ensure_ascii=False, indent=2), encoding="utf-8")


def _euclidean_distance_m(
    a: Tuple[float, float, float],
    b: Tuple[float, float, float],
) -> float:
    """计算 3D 欧氏距离（米）"""
    dx = a[0] - b[0]
    dy = a[1] - b[1]
    dz = a[2] - b[2]
    return math.sqrt(dx * dx + dy * dy + dz * dz)


def _format_distance_m(d: float, decimals: int = 2) -> str:
    """
    将距离格式化为英文自然语言：
    "moved about <distance> m"

    设计说明：
    - 距离数值由外部精确计算，这里只负责语言封装
    - 保留固定小数位，避免模型自行四舍五入或改写
    - 返回的是“可直接复述”的字符串，模型无需再加工
    """
    if d < 0:
        d = 0.0
    return f"moved about {d:.{decimals}f} m"

# %% [markdown]
# ## 4. Prompt 构建

# %%
def build_prompt(objects: List[ObjectSpec]) -> str:
    """
    构建用于“add”任务的多模态 prompt（严格 JSON 输出）：
    - 只提供一张图片：Image B（新增/放置完成之后）
    - 你会给模型一份“目标对象列表”，这些 id 对应的对象就是本次变化中“新增”的对象
    - 用 pixel_center_B 仅用于帮助模型在 Image B 中定位正确对象（输出中禁止提及）
    - 输出中按 id 分别生成：新增了什么（description）+ 能导致该新增的单步放置指令（instructions）
    """

    # 1) 构造 Target objects：仅保留 id + pixel_center_B（用于定位）
    obj_entries: List[Dict[str, Any]] = []
    for o in objects:
        # 优先用 pixel_center_b；如缺失则回退到 pixel_center_a（兜底，不建议依赖）
        center = o.pixel_center_b if o.pixel_center_b is not None else o.pixel_center_a
        entry: Dict[str, Any] = {
            "id": o.object_id,
            "pixel_center_B": [int(center[0]), int(center[1])],
        }
        obj_entries.append(entry)

    # 2) 将对象列表渲染成 JSON-ish 文本（字段顺序稳定）
    obj_lines: List[str] = []
    for e in obj_entries:
        obj_lines.append(f'  {{"id":"{e["id"]}","pixel_center_B":{e["pixel_center_B"]}}}')
    obj_block = "[\n" + ",\n".join(obj_lines) + "\n]"

    # 3) Prompt：只给 Image B；列表中的对象就是“新增对象”
    return f"""
You are given ONE image of a scene: Image B (AFTER an object-addition action).

The target objects listed below are EXACTLY the objects that were newly added to the scene (i.e., the change).
Describe what was added, and write a minimal robot instruction that would cause that addition.

Image resolution: 1024 × 768.
Pixel coordinate system (for reference only; INTERNAL USE ONLY):
- Origin (0, 0) is the top-left corner
- x increases to the right, y increases downward

You will receive a list of target objects with pixel centers in Image B.
Use the pixel centers ONLY to locate the correct objects. Do NOT mention pixel centers in your output.

CRITICAL CONSTRAINTS (MUST FOLLOW):
- Return ONLY valid JSON. No markdown. No extra text.
- The coordinate system and resolution are for internal localization ONLY. Do NOT mention them.
- Do NOT include any pixel coordinates or any other numbers in your output.
- Do NOT write any of: "(x=..., y=...)", "x=", "y=", "pixel", "coordinate", "resolution", "approx.", "approximately".
- Describe locations only using natural scene language (e.g., "left side of the counter", "near the stove", "next to the sink", "on the shelf").
- Do NOT mention any objects that are not in the target list.
- If multiple similar objects exist, disambiguate using visible attributes (e.g., color, material, shape), not numbers.

TASK (for EACH target object id):
1) Description:
   - Write ONE short sentence that conveys the object (as seen in Image B) is newly present in the scene (i.e., it was introduced by the change).
   - You MAY add relative location details (e.g., "on", "near", "beside") ONLY if it makes the description significantly clearer.

2) Robot instruction:
   - Write ONE concise, single-step imperative instruction that would result in that object appearing in the scene as shown in Image B.
   - Keep it minimal (no extra steps).

OUTPUT FORMAT (STRICT JSON):
{{
  "description": [
    {{"id": "<object_id>", "text": ""}},
    ...
  ],
  "instructions": [
    {{"id": "<object_id>", "text": ""}},
    ...
  ]
}}

Target objects (pixel centers are for locating only):
{obj_block}
""".strip()

# %% [markdown]
# ## 5. 响应解析和验证

# %%
def parse_model_output_to_json(text: str) -> Dict[str, Any]:
    """
    鲁棒的 JSON 解析器:
    1) 尝试直接解析
    2) 提取 {...} 块后解析
    3) 回退到旧格式解析
    """
    text = text.strip()

    # 1) 直接解析
    try:
        return json.loads(text)
    except Exception:
        pass

    # 2) 提取 JSON 对象
    m = re.search(r"\{.*\}", text, flags=re.DOTALL)
    if m:
        try:
            return json.loads(m.group(0))
        except Exception:
            pass

    # 3) 回退解析旧格式
    desc_match = re.search(r"description\s*:\s*\[(.*?)\]", text, flags=re.DOTALL | re.IGNORECASE)
    inst_match = re.search(r"instructions\s*:\s*\[(.*?)\]", text, flags=re.DOTALL | re.IGNORECASE)
    if desc_match and inst_match:
        def _parse_list_body(body: str) -> List[str]:
            return re.findall(r"\"(.*?)\"", body, flags=re.DOTALL)

        desc_list = _parse_list_body(desc_match.group(1))
        inst_list = _parse_list_body(inst_match.group(1))
        return {
            "description": [{"id": str(i), "text": t} for i, t in enumerate(desc_list)],
            "instructions": [{"id": str(i), "text": t} for i, t in enumerate(inst_list)],
            "_warning": "Parsed legacy format; IDs are enumerated, not the original object IDs."
        }

    raise ValueError("Failed to parse model output as JSON. Raw text:\n" + text)


def validate_result(result: Dict[str, Any], object_ids: List[str]) -> None:
    """
    验证结果是否包含所有对象。
    """
    desc = result.get("description", [])
    inst = result.get("instructions", [])
    if not isinstance(desc, list) or not isinstance(inst, list):
        raise ValueError("JSON schema error: 'description' and 'instructions' must be lists.")

    if len(desc) != len(inst):
        raise ValueError("JSON schema error: 'description' and 'instructions' length mismatch.")

    got_ids_desc = [x.get("id") for x in desc if isinstance(x, dict)]
    got_ids_inst = [x.get("id") for x in inst if isinstance(x, dict)]
    if got_ids_desc != got_ids_inst:
        raise ValueError("Order/ID mismatch between description and instructions.")

    missing = [oid for oid in object_ids if oid not in got_ids_desc]
    if missing:
        raise ValueError(f"Missing objects in output: {missing}")


print("解析和验证函数定义完成！")
# Out:
# 解析和验证函数定义完成！

# %% [markdown]
# ## 6. OpenAI API 调用

# %%
def run_add(
    image_b_path: str,
    objects: List[ObjectSpec],
    model: str = "gpt-4o-mini",
    max_output_tokens: int = 800,
) -> Dict[str, Any]:
    """
    使用 OpenAI Chat Completions API 处理“add”任务：
    - 只输入一张图片（B，放置/添加后）
    - 模型输出每个 id 的 placed 描述与 place 指令（严格 JSON）
    """
    client = OpenAI()

    prompt = build_prompt(objects)
    img_b = image_to_data_url(image_b_path)

    # 构建消息内容（只发送 Image B）
    content = [
        {"type": "text", "text": prompt},
        {"type": "text", "text": "Image B:"},
        {"type": "image_url", "image_url": {"url": img_b}},
    ]

    resp = client.chat.completions.create(
        model=model,
        messages=[
            {
                "role": "user",
                "content": content,
            }
        ],
        max_completion_tokens=max_output_tokens,
    )

    # 提取响应文本
    text = resp.choices[0].message.content
    result = parse_model_output_to_json(text)

    object_ids = [o.object_id for o in objects]
    validate_result(result, object_ids)
    return result


print("API 调用函数定义完成！")
# Out:
# API 调用函数定义完成！

# %% [markdown]
# ## 7. Metadata 读取和批量处理

# %%
def load_objects_from_metadata(metadata_path: str) -> List[ObjectSpec]:
    """
    从 metadata.json 中读取对象坐标信息（add 任务）。
    只需要 pixel_center_B（用于在 Image B 中定位被放置/添加的对象）。
    """
    data = json.loads(Path(metadata_path).read_text(encoding="utf-8"))
    coordinates = data.get("coordinates", {})

    out: List[ObjectSpec] = []
    for obj_id, coords in coordinates.items():
        pixel_b = coords.get("pixel_center_B")

        # 跳过缺少必要坐标的对象
        if pixel_b is None:
            continue

        # 使用对象路径的最后一部分作为简短 ID
        short_id = obj_id.split("/")[-1]

        # ObjectSpec 的 pixel_center_a 是必填字段，这里用 B 的坐标填充；
        # 真实用于定位的是 pixel_center_b。
        out.append(
            ObjectSpec(
                object_id=short_id,
                pixel_center_a=tuple(pixel_b),
                pixel_center_b=tuple(pixel_b),
            )
        )

    return out


def process_pair_folder(
    pair_folder: str,
    model: str = "gpt-4o-mini",
    max_output_tokens: int = 800,
) -> Optional[Dict[str, Any]]:
    """
    处理单个 pair 文件夹（add）：
    - 只读取 B_rgb.png（放置/添加后）
    - 从 metadata.json 读取 pixel_center_B
    - 调用模型输出 placed 描述并保存 result.json
    """
    pair_path = Path(pair_folder)

    # 已生成过则直接跳过
    output_file = pair_path / "result.json"
    if output_file.exists():
        print(f"  [SKIP] Existing result.json in {pair_folder}")
        return None

    # 检查必要文件是否存在
    image_b = pair_path / "B_rgb.png"
    metadata_file = pair_path / "metadata.json"

    if not image_b.exists():
        print(f"  [SKIP] Missing B_rgb.png in {pair_folder}")
        return None
    if not metadata_file.exists():
        print(f"  [SKIP] Missing metadata.json in {pair_folder}")
        return None

    # 从 metadata.json 加载对象
    objects = load_objects_from_metadata(str(metadata_file))

    if not objects:
        print(f"  [SKIP] No valid objects with pixel_center_B in {pair_folder}")
        return None

    print(f"  Found {len(objects)} objects with pixel_center_B: {[o.object_id for o in objects]}")

    # 调用 API 生成 add 描述
    result = run_add(
        image_b_path=str(image_b),
        objects=objects,
        model=model,
        max_output_tokens=max_output_tokens,
    )

    # 保存结果
    output_file = pair_path / "result.json"
    save_json(str(output_file), result)
    print(f"  [OK] Saved: {output_file}")

    return result


def _find_pair_folders(input_path: Path) -> List[Path]:
    """在 input_path 下查找所有 pair_* 文件夹。

    兼容两种目录结构：
    - input_path/pair_0000/
    - input_path/<split>/pair_0000/（例如 0-19、20-39 等）
    """

    # 1) 先尝试当前目录的直接子目录（最快）
    direct = sorted([d for d in input_path.iterdir() if d.is_dir() and d.name.startswith("pair_")])
    if direct:
        return direct

    # 2) 否则递归查找（支持更上一级目录）
    return sorted([p for p in input_path.rglob("pair_*") if p.is_dir()])


def process_all_pairs(
    input_dir: str,
    model: str = "gpt-4o-mini",
    max_output_tokens: int = 800,
) -> Dict[str, Any]:
    """遍历 input_dir 下所有 pair_* 文件夹并处理（支持多层目录）。"""
    input_path = Path(input_dir)

    if not input_path.is_dir():
        raise ValueError(f"Input directory does not exist: {input_dir}")

    pair_folders = _find_pair_folders(input_path)

    if not pair_folders:
        print(f"No pair_* folders found under: {input_dir}")
        return {"total": 0, "success": 0, "skipped": 0, "failed": 0}

    print(f"Found {len(pair_folders)} pair folders to process")
    print("-" * 50)

    stats = {"total": len(pair_folders), "success": 0, "skipped": 0, "failed": 0}

    for i, pair_folder in enumerate(pair_folders, 1):
        # 用相对路径打印，便于看出属于哪个子目录
        try:
            rel = str(pair_folder.relative_to(input_path))
        except Exception:
            rel = pair_folder.name

        print(f"\n[{i}/{len(pair_folders)}] Processing: {rel}")
        try:
            result = process_pair_folder(
                str(pair_folder),
                model=model,
                max_output_tokens=max_output_tokens,
            )
            if result is not None:
                stats["success"] += 1
            else:
                stats["skipped"] += 1
        except Exception as e:
            print(f"  [ERROR] Failed: {e}")
            stats["failed"] += 1

    print("\n" + "=" * 50)
    print("Processing complete!")
    print(f"  Total: {stats['total']}")
    print(f"  Success: {stats['success']}")
    print(f"  Skipped: {stats['skipped']}")
    print(f"  Failed: {stats['failed']}")

    return stats


print("批量处理函数定义完成！")
# Out:
# 批量处理函数定义完成！

# %% [markdown]
# ## 8. 执行批量处理
#
# 运行下面的单元格开始处理所有图片对

# %%
# 开始处理！
stats = process_all_pairs(
    input_dir=INPUT_DIR,
    model=MODEL,
    max_output_tokens=MAX_OUTPUT_TOKENS,
)
# Out:
# Found 220 pair folders to process
# --------------------------------------------------
#
# [1/220] Processing: pair_0000
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0000
#
# [2/220] Processing: pair_0001
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0001
#
# [3/220] Processing: pair_0002
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0002
#
# [4/220] Processing: pair_0003
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0003
#
# [5/220] Processing: pair_0004
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0004
#
# [6/220] Processing: pair_0005
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0005
#
# [7/220] Processing: pair_0006
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0006
#
# [8/220] Processing: pair_0007
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0007
#
# [9/220] Processing: pair_0008
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0008
#
# [10/220] Processing: pair_0009
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0009
#
# [11/220] Processing: pair_0010
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0010
#
# [12/220] Processing: pair_0011
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0011
#
# [13/220] Processing: pair_0012
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0012
#
# [14/220] Processing: pair_0013
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0013
#
# [15/220] Processing: pair_0014
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0014
#
# [16/220] Processing: pair_0015
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0015
#
# [17/220] Processing: pair_0016
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0016
#
# [18/220] Processing: pair_0017
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0017
#
# [19/220] Processing: pair_0018
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0018
#
# [20/220] Processing: pair_0019
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0019
#
# [21/220] Processing: pair_0020
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0020
#
# [22/220] Processing: pair_0021
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0021
#
# [23/220] Processing: pair_0022
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0022
#
# [24/220] Processing: pair_0023
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0023
#
# [25/220] Processing: pair_0024
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0024
#
# [26/220] Processing: pair_0025
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0025
#
# [27/220] Processing: pair_0026
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0026
#
# [28/220] Processing: pair_0027
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0027
#
# [29/220] Processing: pair_0028
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0028
#
# [30/220] Processing: pair_0029
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0029
#
# [31/220] Processing: pair_0030
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0030
#
# [32/220] Processing: pair_0031
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0031
#
# [33/220] Processing: pair_0032
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0032
#
# [34/220] Processing: pair_0033
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0033
#
# [35/220] Processing: pair_0034
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0034
#
# [36/220] Processing: pair_0035
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0035
#
# [37/220] Processing: pair_0036
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0036
#
# [38/220] Processing: pair_0037
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0037
#
# [39/220] Processing: pair_0038
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0038
#
# [40/220] Processing: pair_0039
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0039
#
# [41/220] Processing: pair_0040
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0040
#
# [42/220] Processing: pair_0041
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0041
#
# [43/220] Processing: pair_0042
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0042
#
# [44/220] Processing: pair_0043
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0043
#
# [45/220] Processing: pair_0044
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0044
#
# [46/220] Processing: pair_0045
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0045
#
# [47/220] Processing: pair_0046
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0046
#
# [48/220] Processing: pair_0047
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0047
#
# [49/220] Processing: pair_0048
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0048
#
# [50/220] Processing: pair_0049
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0049
#
# [51/220] Processing: pair_0050
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0050
#
# [52/220] Processing: pair_0051
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0051
#
# [53/220] Processing: pair_0052
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0052
#
# [54/220] Processing: pair_0053
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0053
#
# [55/220] Processing: pair_0054
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0054
#
# [56/220] Processing: pair_0055
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0055
#
# [57/220] Processing: pair_0056
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0056
#
# [58/220] Processing: pair_0057
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0057
#
# [59/220] Processing: pair_0058
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0058
#
# [60/220] Processing: pair_0059
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0059
#
# [61/220] Processing: pair_0060
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0060
#
# [62/220] Processing: pair_0061
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0061
#
# [63/220] Processing: pair_0062
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0062
#
# [64/220] Processing: pair_0063
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0063
#
# [65/220] Processing: pair_0064
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0064
#
# [66/220] Processing: pair_0065
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0065
#
# [67/220] Processing: pair_0066
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0066
#
# [68/220] Processing: pair_0067
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0067
#
# [69/220] Processing: pair_0068
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0068
#
# [70/220] Processing: pair_0069
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0069
#
# [71/220] Processing: pair_0070
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0070
#
# [72/220] Processing: pair_0071
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0071
#
# [73/220] Processing: pair_0072
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0072
#
# [74/220] Processing: pair_0073
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0073
#
# [75/220] Processing: pair_0074
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0074
#
# [76/220] Processing: pair_0075
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0075
#
# [77/220] Processing: pair_0076
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0076
#
# [78/220] Processing: pair_0077
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0077
#
# [79/220] Processing: pair_0078
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0078
#
# [80/220] Processing: pair_0079
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0079
#
# [81/220] Processing: pair_0080
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0080
#
# [82/220] Processing: pair_0081
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0081
#
# [83/220] Processing: pair_0082
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0082
#
# [84/220] Processing: pair_0083
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0083
#
# [85/220] Processing: pair_0084
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0084
#
# [86/220] Processing: pair_0085
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0085
#
# [87/220] Processing: pair_0086
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0086
#
# [88/220] Processing: pair_0087
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0087
#
# [89/220] Processing: pair_0088
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0088
#
# [90/220] Processing: pair_0089
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0089
#
# [91/220] Processing: pair_0090
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0090
#
# [92/220] Processing: pair_0091
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0091
#
# [93/220] Processing: pair_0092
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0092
#
# [94/220] Processing: pair_0093
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0093
#
# [95/220] Processing: pair_0094
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0094
#
# [96/220] Processing: pair_0095
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0095
#
# [97/220] Processing: pair_0096
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0096
#
# [98/220] Processing: pair_0097
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0097
#
# [99/220] Processing: pair_0098
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0098
#
# [100/220] Processing: pair_0099
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0099
#
# [101/220] Processing: pair_0100
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0100
#
# [102/220] Processing: pair_0101
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0101
#
# [103/220] Processing: pair_0102
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0102
#
# [104/220] Processing: pair_0103
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0103
#
# [105/220] Processing: pair_0104
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0104
#
# [106/220] Processing: pair_0105
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0105
#
# [107/220] Processing: pair_0106
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0106
#
# [108/220] Processing: pair_0107
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0107
#
# [109/220] Processing: pair_0108
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0108
#
# [110/220] Processing: pair_0109
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0109
#
# [111/220] Processing: pair_0110
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0110
#
# [112/220] Processing: pair_0111
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0111
#
# [113/220] Processing: pair_0112
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0112
#
# [114/220] Processing: pair_0113
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0113
#
# [115/220] Processing: pair_0114
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0114
#
# [116/220] Processing: pair_0115
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0115
#
# [117/220] Processing: pair_0116
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0116
#
# [118/220] Processing: pair_0117
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0117
#
# [119/220] Processing: pair_0118
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0118
#
# [120/220] Processing: pair_0119
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0119
#
# [121/220] Processing: pair_0120
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0120
#
# [122/220] Processing: pair_0121
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0121
#
# [123/220] Processing: pair_0122
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0122
#
# [124/220] Processing: pair_0123
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0123
#
# [125/220] Processing: pair_0124
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0124
#
# [126/220] Processing: pair_0125
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0125
#
# [127/220] Processing: pair_0126
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0126
#
# [128/220] Processing: pair_0127
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0127
#
# [129/220] Processing: pair_0128
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0128
#
# [130/220] Processing: pair_0129
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0129
#
# [131/220] Processing: pair_0130
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0130
#
# [132/220] Processing: pair_0131
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0131
#
# [133/220] Processing: pair_0132
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0132
#
# [134/220] Processing: pair_0133
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0133
#
# [135/220] Processing: pair_0134
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0134
#
# [136/220] Processing: pair_0135
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0135
#
# [137/220] Processing: pair_0136
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0136
#
# [138/220] Processing: pair_0137
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0137
#
# [139/220] Processing: pair_0138
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0138
#
# [140/220] Processing: pair_0139
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0139
#
# [141/220] Processing: pair_0140
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0140
#
# [142/220] Processing: pair_0141
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0141
#
# [143/220] Processing: pair_0142
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0142
#
# [144/220] Processing: pair_0143
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0143
#
# [145/220] Processing: pair_0144
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0144
#
# [146/220] Processing: pair_0145
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0145
#
# [147/220] Processing: pair_0146
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0146
#
# [148/220] Processing: pair_0147
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0147
#
# [149/220] Processing: pair_0148
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0148
#
# [150/220] Processing: pair_0149
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0149
#
# [151/220] Processing: pair_0150
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0150
#
# [152/220] Processing: pair_0151
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0151
#
# [153/220] Processing: pair_0152
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0152
#
# [154/220] Processing: pair_0153
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0153
#
# [155/220] Processing: pair_0154
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0154
#
# [156/220] Processing: pair_0155
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0155
#
# [157/220] Processing: pair_0156
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0156
#
# [158/220] Processing: pair_0157
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0157
#
# [159/220] Processing: pair_0158
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0158
#
# [160/220] Processing: pair_0159
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0159
#
# [161/220] Processing: pair_0160
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0160
#
# [162/220] Processing: pair_0161
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0161
#
# [163/220] Processing: pair_0162
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0162
#
# [164/220] Processing: pair_0163
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0163
#
# [165/220] Processing: pair_0164
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0164
#
# [166/220] Processing: pair_0165
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0165
#
# [167/220] Processing: pair_0166
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0166
#
# [168/220] Processing: pair_0167
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0167
#
# [169/220] Processing: pair_0168
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0168
#
# [170/220] Processing: pair_0169
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0169
#
# [171/220] Processing: pair_0170
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0170
#
# [172/220] Processing: pair_0171
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0171
#
# [173/220] Processing: pair_0172
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0172
#
# [174/220] Processing: pair_0173
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0173
#
# [175/220] Processing: pair_0174
#   Found 3 objects with pixel_center_B: ['book_0029', 'table_0006', 'TV_box_0000']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0174/result.json
#
# [176/220] Processing: pair_0175
#   Found 3 objects with pixel_center_B: ['vase_0019', 'table_0008', 'TV_box_0000']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0175/result.json
#
# [177/220] Processing: pair_0176
#   Found 3 objects with pixel_center_B: ['vase_0019', 'table_0008', 'book_0029']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0176/result.json
#
# [178/220] Processing: pair_0177
#   Found 3 objects with pixel_center_B: ['vase_0020', 'vase_0019', 'book_0029']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0177/result.json
#
# [179/220] Processing: pair_0178
#   Found 3 objects with pixel_center_B: ['plate_0000', 'vase_0019', 'book_0029']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0178/result.json
#
# [180/220] Processing: pair_0179
#   Found 3 objects with pixel_center_B: ['vase_0019', 'plate_0000', 'book_0029']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0179/result.json
#
# [181/220] Processing: pair_0180
#   Found 3 objects with pixel_center_B: ['table_0008', 'plate_0000', 'vase_0019']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0180/result.json
#
# [182/220] Processing: pair_0181
#   Found 3 objects with pixel_center_B: ['TV_box_0000', 'book_0029', 'vase_0020']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0181/result.json
#
# [183/220] Processing: pair_0182
#   Found 3 objects with pixel_center_B: ['vase_0020', 'vase_0019', 'table_0006']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0182/result.json
#
# [184/220] Processing: pair_0183
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0183
#
# [185/220] Processing: pair_0184
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0184
#
# [186/220] Processing: pair_0185
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0185
#
# [187/220] Processing: pair_0186
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0186
#
# [188/220] Processing: pair_0187
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0187
#
# [189/220] Processing: pair_0188
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0188
#
# [190/220] Processing: pair_0189
#   [SKIP] Existing result.json in /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0189
#
# [191/220] Processing: pair_0190
#   Found 3 objects with pixel_center_B: ['plate_0000', 'table_0006', 'TV_box_0000']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0190/result.json
#
# [192/220] Processing: pair_0191
#   Found 3 objects with pixel_center_B: ['vase_0020', 'TV_box_0000', 'plate_0000']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0191/result.json
#
# [193/220] Processing: pair_0192
#   Found 3 objects with pixel_center_B: ['book_0029', 'plate_0000', 'vase_0020']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0192/result.json
#
# [194/220] Processing: pair_0193
#   Found 3 objects with pixel_center_B: ['book_0029', 'vase_0020', 'table_0008']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0193/result.json
#
# [195/220] Processing: pair_0194
#   Found 3 objects with pixel_center_B: ['vase_0019', 'book_0029', 'TV_box_0000']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0194/result.json
#
# [196/220] Processing: pair_0195
#   Found 3 objects with pixel_center_B: ['table_0006', 'vase_0020', 'TV_box_0000']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0195/result.json
#
# [197/220] Processing: pair_0196
#   Found 3 objects with pixel_center_B: ['vase_0019', 'table_0008', 'book_0029']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0196/result.json
#
# [198/220] Processing: pair_0197
#   Found 3 objects with pixel_center_B: ['table_0008', 'TV_box_0000', 'book_0029']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0197/result.json
#
# [199/220] Processing: pair_0198
#   Found 3 objects with pixel_center_B: ['vase_0019', 'table_0006', 'vase_0020']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0198/result.json
#
# [200/220] Processing: pair_0199
#   Found 3 objects with pixel_center_B: ['book_0029', 'table_0008', 'plate_0000']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0199/result.json
#
# [201/220] Processing: pair_0200
#   Found 3 objects with pixel_center_B: ['table_0008', 'book_0029', 'vase_0020']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0200/result.json
#
# [202/220] Processing: pair_0201
#   Found 3 objects with pixel_center_B: ['TV_box_0000', 'table_0008', 'table_0006']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0201/result.json
#
# [203/220] Processing: pair_0202
#   Found 3 objects with pixel_center_B: ['plate_0000', 'book_0029', 'vase_0019']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0202/result.json
#
# [204/220] Processing: pair_0203
#   Found 3 objects with pixel_center_B: ['vase_0019', 'table_0008', 'vase_0020']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0203/result.json
#
# [205/220] Processing: pair_0204
#   Found 3 objects with pixel_center_B: ['table_0006', 'book_0029', 'vase_0020']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0204/result.json
#
# [206/220] Processing: pair_0205
#   Found 3 objects with pixel_center_B: ['vase_0020', 'plate_0000', 'table_0006']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0205/result.json
#
# [207/220] Processing: pair_0206
#   Found 3 objects with pixel_center_B: ['book_0029', 'TV_box_0000', 'table_0006']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0206/result.json
#
# [208/220] Processing: pair_0207
#   Found 3 objects with pixel_center_B: ['TV_box_0000', 'vase_0019', 'table_0008']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0207/result.json
#
# [209/220] Processing: pair_0208
#   Found 3 objects with pixel_center_B: ['table_0008', 'vase_0020', 'plate_0000']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0208/result.json
#
# [210/220] Processing: pair_0209
#   Found 3 objects with pixel_center_B: ['TV_box_0000', 'vase_0019', 'plate_0000']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0209/result.json
#
# [211/220] Processing: pair_0210
#   Found 3 objects with pixel_center_B: ['vase_0019', 'book_0029', 'plate_0000']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0210/result.json
#
# [212/220] Processing: pair_0211
#   Found 3 objects with pixel_center_B: ['table_0006', 'table_0008', 'book_0029']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0211/result.json
#
# [213/220] Processing: pair_0212
#   Found 3 objects with pixel_center_B: ['vase_0019', 'plate_0000', 'table_0008']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0212/result.json
#
# [214/220] Processing: pair_0213
#   Found 3 objects with pixel_center_B: ['book_0029', 'vase_0019', 'plate_0000']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0213/result.json
#
# [215/220] Processing: pair_0214
#   Found 3 objects with pixel_center_B: ['table_0008', 'book_0029', 'vase_0020']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0214/result.json
#
# [216/220] Processing: pair_0215
#   Found 3 objects with pixel_center_B: ['plate_0000', 'table_0008', 'vase_0019']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0215/result.json
#
# [217/220] Processing: pair_0216
#   Found 3 objects with pixel_center_B: ['vase_0019', 'book_0029', 'vase_0020']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0216/result.json
#
# [218/220] Processing: pair_0217
#   Found 3 objects with pixel_center_B: ['TV_box_0000', 'plate_0000', 'vase_0020']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0217/result.json
#
# [219/220] Processing: pair_0218
#   Found 3 objects with pixel_center_B: ['vase_0019', 'plate_0000', 'book_0029']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0218/result.json
#
# [220/220] Processing: pair_0219
#   Found 3 objects with pixel_center_B: ['vase_0020', 'TV_box_0000', 'book_0029']
#   [OK] Saved: /home/lican/workarea/Songwei/synthetic-data-examples/output/livingroom_add/3_items/pair_0219/result.json
#
# ==================================================
# Processing complete!
#   Total: 220
#   Success: 39
#   Skipped: 181
#   Failed: 0

# %% [markdown]
# ## 9. 查看结果示例（可选）

# %%
# 查看第一个处理成功的结果
from IPython.display import JSON, display

input_path = Path(INPUT_DIR)
pair_folders = sorted([d for d in input_path.iterdir() if d.is_dir() and d.name.startswith("pair_")])

for pair_folder in pair_folders:
    result_file = pair_folder / "result.json"
    if result_file.exists():
        print(f"Result from: {pair_folder.name}")
        result = json.loads(result_file.read_text(encoding="utf-8"))
        display(JSON(result))
        break
else:
    print("No result.json files found.")
# Out:
# Result from: pair_0000

# %%
# 显示图片A/B（可选，用于肉眼对比；不影响 remove 主流程只用 A 图推理）
import matplotlib.pyplot as plt

if pair_folders:
    first_pair = pair_folders[0]

    img_a = plt.imread(first_pair / "A_rgb.png")

    # B 可能不存在（取决于你的数据组织），不存在则只展示 A
    b_path = first_pair / "B_rgb.png"
    img_b = plt.imread(b_path) if b_path.exists() else None

    if img_b is None:
        plt.figure(figsize=(8, 6))
        plt.imshow(img_a)
        plt.title("Image A")
        plt.axis("off")
        plt.tight_layout()
        plt.show()
    else:
        fig, axes = plt.subplots(1, 2, figsize=(16, 8))

        axes[0].imshow(img_a)
        axes[0].set_title("Image A")
        axes[0].axis("off")

        axes[1].imshow(img_b)
        axes[1].set_title("Image B")
        axes[1].axis("off")

        plt.tight_layout()
        plt.show()
